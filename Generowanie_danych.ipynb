# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %% [markdown]
# Konfiguracje spinów

# %% [markdown]
# **L=10, T=1** uporządkowane

# %%
col_map = LinearSegmentedColormap.from_list('col_map', [(0,0,0),(0.92, 0.2, 0.66)], N=2)
col_map2 = LinearSegmentedColormap.from_list('col_map', [(0.92, 0.2, 0.66),(0.92, 0.2, 0.66)], N=2)

# %%
L10_T1 = []
for i in [0,100,1000,4000,8000]:
    L10_T1.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L10\\L10_T1_'+str(i)+'.txt'))

# %%
plt.imshow(L10_T1[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1[1], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T1[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T1[4], cmap=col_map2)
plt.show()

# %% [markdown]
# **L=10, T=2.26**

# %%
L10_T2 = []
for i in [0,100,1000,4000,8000]:
    L10_T2.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L10\\L10_T2_'+str(i)+'.txt'))

# %%
plt.imshow(L10_T2[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T2[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2[4], cmap=col_map)
plt.show()

# %% [markdown]
# **L=10, T=4**

# %%
L10_T3 = []
for i in [0,100,1000,4000,8000]:
    L10_T3.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L10\\L10_T3_'+str(i)+'.txt'))

# %%
plt.imshow(L10_T3[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T3[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3[4], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=1** uporządkowane

# %%
L100_T1 = []
for i in [0,1000,4000,7000,10000]:
    L100_T1.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L100\\L100_T1_'+str(i)+'.txt'))

# %%
plt.imshow(L100_T1[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L100_T1[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1[4], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=2.26**

# %%
L100_T2 = []
for i in [0,1000,4000,7000,10000]:
    L100_T2.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L100\\L100_T2_'+str(i)+'.txt'))

# %%
plt.imshow(L100_T2[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L100_T2[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2[4], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=4**

# %%
L100_T3 = []
for i in [0,1000,4000,7000,10000]:
    L100_T3.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L100\\L100_T3_'+str(i)+'.txt'))

# %%
plt.imshow(L100_T3[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L100_T3[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3[4], cmap=col_map)
plt.show()

# %% [markdown]
# **L=10, T=1** nieuporządkowane

# %%
L10_T1_uno = []
for i in [0,100,1000,4000,8000]:
    L10_T1_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L10_UNO\\L10_T1_UNO_'+str(i)+'.txt'))

# %%
plt.imshow(L10_T1_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T1_uno[1], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1_uno[2], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1_uno[3], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1_uno[4], cmap=col_map2)
plt.show()

# %% [markdown]
# **L=10, T=2.26** nieuporządkowane

# %%
L10_T2_uno = []
for i in [0,100,1000,4000,8000]:
    L10_T2_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L10_UNO\\L10_T2_UNO_'+str(i)+'.txt'))

# %%
plt.imshow(L10_T2_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[4], cmap=col_map)
plt.show()

# %% [markdown]
# **L=10, T=4** nieuporządkowane

# %%
L10_T3_uno = []
for i in [0,100,1000,4000,8000]:
    L10_T3_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L10_UNO\\L10_T3_UNO_'+str(i)+'.txt'))

# %%
plt.imshow(L10_T3_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[4], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=1** nieuporządkowane

# %%
L100_T1_uno = []
for i in [0,100,1000,4000,8000]:
    L100_T1_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L100_UNO\\L100_T1_UNO_'+str(i)+'.txt'))

# %%
plt.imshow(L100_T1_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[4], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=2.26** nieuporządkowane

# %%
L100_T2_uno = []
for i in [0,100,1000,4000,8000]:
    L100_T2_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L100_UNO\\L100_T2_UNO_'+str(i)+'.txt'))

# %%
plt.imshow(L100_T2_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[4], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=4** nieuporządkowane

# %%
L100_T3_uno = []
for i in [0,100,1000,4000,8000]:
    L100_T3_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\L100_UNO\\L100_T3_UNO_'+str(i)+'.txt'))

# %%
plt.imshow(L100_T3_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[1], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[2], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[3], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[4], cmap=col_map)
plt.show()

# %% [markdown]
# TRAJEKTORIE

# %% [markdown]
# L=10, T=1.7

# %%
m10 = []
for i in range(1,7):
    m10.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\trajektorie_10\\m10_T1.7'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m10[:6]:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4,0,1])
plt.title('Trajektorie L=10 dla T*=1.7',fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.show()

# %% [markdown]
# L=50, T=1.7

# %%
m50 = []
for i in range(1,7):
    m50.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\trajektorie_50\\m50_T1.7'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m50:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4,0.92,1])
plt.title('Trajektorie L=50 dla T*=1.7',fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.show()

# %% [markdown]
# L=100, T=1.7

# %%
m100 = []
for i in range(1,7):
    m100.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\trajektorie_100\\m100_T1.7'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m100:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4,0.94,1])
plt.title('Trajektorie L=100 dla T*=1.7',fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.show()

# %% [markdown]
# NIEUPORZĄDKOWANE

# %% [markdown]
# L=10, T=1.7

# %%
m10_uno = []
for i in range(10):
    m10_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\trajektorie_10_uno\\m10_uno'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m10_uno:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4, -1, 1])
plt.title('Trajektorie dla L=10, T*=1.7', fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.show()

# %% [markdown]
# L=50, T=1.7

# %%
m50_uno = []
for i in range(10):
    m50_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\trajektorie_50_uno\\m50_uno'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m50_uno:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4, -1, 1])
plt.title('Trajektorie dla L=50, T*=1.7', fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.show()

# %% [markdown]
# L=100, T=1.7

# %%
m100_uno = []
for i in range(10):
    m100_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\trajektorie_100_uno\\m100_uno'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m100_uno:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4, -1, 1])
plt.title('Trajektorie dla L=100, T*=1.7', fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.show()

# %% [markdown]
# MAGNETYZACJA

# %% [markdown]
# ŚREDNIA PO CZASIE

# %%
t_range = np.arange(1,2,0.2)
t_range = np.append(t_range,np.arange(2,2.6,0.05)[:-1])
t_range = np.append(t_range,np.arange(2.6,3.5,0.2))

# %%
mag_10 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\średnia i podatność\\magnetyzacja_10.txt')
mag_50 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\średnia i podatność\\magnetyzacja_50.txt')
mag_100 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\średnia i podatność\\magnetyzacja_100.txt')

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range, mag_10, '-o', color='hotpink', label='L=10')
plt.plot(t_range, mag_50, '-o', color='purple', label='L=50')
plt.plot(t_range, mag_100, '-o', color='skyblue', label='L=100')
plt.grid()
plt.legend()
plt.title('<m>(T*)',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('<m>', fontsize=15)
plt.show()

# %% [markdown]
# ŚREDNIA PO ZESPOLE

# %%
t_range2 = np.arange(1,2,0.3)
t_range2 = np.append(t_range2,np.arange(2,2.6,0.1)[:-1])
t_range2 = np.append(t_range2,np.arange(2.6,3.6,0.3))

# %%
mag_10_zesp = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\średnia i podatność\\magnetyzacja_10_zesp.txt')
mag_50_zesp = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\średnia i podatność\\magnetyzacja_50_zesp.txt')
mag_100_zesp = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\średnia i podatność\\magnetyzacja_100_zesp.txt')

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range2, mag_10_zesp, '-o', color='hotpink', label='L=10')
plt.plot(t_range2, mag_50_zesp, '-o', color='purple', label='L=50')
plt.plot(t_range2, mag_100_zesp, '-o', color='skyblue', label='L=100')
plt.grid()
plt.legend()
plt.title('<m>(T*)',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('<m>', fontsize=15)
plt.show()

# %% [markdown]
# PODATNOŚĆ MAGNETYCZNA

# %%
pod_10 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\średnia i podatność\\podatność_10.txt')
pod_50 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\średnia i podatność\\podatność_50.txt')
pod_100 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\średnia i podatność\\podatność_100.txt')

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range, pod_10, '-o', color='hotpink', label='L=10')
plt.plot(t_range, pod_50, '-o', color='purple', label='L=50')
plt.plot(t_range, pod_100, '-o', color='skyblue', label='L=100')
plt.grid()
plt.legend()
plt.title('\u03C7(T*) ',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('\u03C7', fontsize=15)
plt.show()

# %% [markdown]
# Rozkład magnetyzacji, T=1.7

# %%
roz_17 = []
for i in [0,100,1000,2000,10000,100000]:
    roz_17.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\rozkład magnetyzacji\\rozkład_1_7_t'+str(i)+'.txt'))

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_17[0], density=True)
plt.xlim([-1,1])
plt.title('t=0', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_17[1], bins=30, density=True)
plt.xlim([-1,1])
plt.title('t=100', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_17[2], bins=30, density=True)
plt.title('t=1000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_17[3], bins=30, density=True)
plt.title('t=2000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_17[4], bins=30, density=True)
plt.title('t=10000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_17[5], bins=30, density=True)
plt.title('t=100000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %% [markdown]
# Rozkład magnetyzacji, T=2.26

# %%
roz_226 = []
for i in [0,100,1000,2000,10000,100000]:
    roz_226.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\rozkład magnetyzacji\\rozkład_2_26_t'+str(i)+'.txt'))

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_226[0], density=True)
plt.xlim([-1,1])
plt.title('t=0', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_226[1], bins=20, density=True)
plt.xlim([-1,1])
plt.title('t=100', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_226[2], bins=40, density=True)
plt.xlim([-1,1])
plt.title('t=1000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_226[3], bins=30, density=True)
plt.xlim([-1,1])
plt.title('t=2000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_226[4], bins=30, density=True)
plt.xlim([-1,1])
plt.title('t=10000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(roz_226[5], bins=30, density=True)
plt.xlim([-1,1])
plt.title('t=100000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.show()

# %% [markdown]
# DYNAMIKA GLAUBERA

# %%
m10_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\glauber\\magnetyzacja_10_g.txt')
m50_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\glauber\\magnetyzacja_50_g.txt')
m100_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\glauber\\magnetyzacja_100_g.txt')

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range, m10_g, '-o', color='hotpink', label='L=10')
plt.plot(t_range, m50_g, '-o', color='purple', label='L=50')
plt.plot(t_range, m100_g, '-o', color='skyblue', label='L=100')
plt.legend()
plt.grid()
plt.title('<m>(T*)',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('<m>', fontsize=15)
plt.show()

# %%
pod10_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\glauber\\podatność_10_g.txt')
pod50_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\glauber\\podatność_50_g.txt')
pod100_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\data\\glauber\\podatność_100_g.txt')

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range, pod10_g, '-o', color='hotpink', label='L=10')
plt.plot(t_range, pod50_g, '-o', color='purple', label='L=50')
plt.plot(t_range, pod100_g, '-o', color='skyblue', label='L=100')
plt.grid()
plt.legend()
plt.title('\u03C7(T*) ',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('\u03C7', fontsize=15)
plt.show()

# %% [markdown]
# PORÓWNANIE DYNAMIK METROPOLISA I GLAUBERA

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range, m10_g, '-o', color='hotpink', label='G, L=10')
plt.plot(t_range, m50_g, '-o', color='purple', label='G, L=50')
plt.plot(t_range, m100_g, '-o', color='deepskyblue', label='G, L=100')
plt.plot(t_range,mag_10, '-<', color='pink', label='M, L=10')
plt.plot(t_range,mag_50, '-<', color='violet', label='M, L=50')
plt.plot(t_range,mag_100, '-<', color='skyblue', label='M, L=100')
plt.grid()
plt.legend()
plt.title('<m>(T*)',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('<m>', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range,pod10_g, '-o', color='hotpink', label='G, L=10')
plt.plot(t_range,pod50_g, '-o', color='purple', label='G, L=50')
plt.plot(t_range,pod100_g, '-o', color='deepskyblue', label='G, L=100')
plt.plot(t_range,pod_10, '-<', color='pink', label='M, L=10')
plt.plot(t_range,pod_50, '-<', color='violet', label='M, L=50')
plt.plot(t_range,pod_100, '-<', color='skyblue', label='M, L=100')
plt.grid()
plt.legend()
plt.title('\u03C7(T*) ',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('\u03C7', fontsize=15)
plt.show()
