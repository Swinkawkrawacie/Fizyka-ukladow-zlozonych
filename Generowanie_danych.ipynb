# %%
import numpy as np
import math
import random
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %% [markdown]
# Algorytm Metropolisa

# %% [markdown]
# **L=10, T=1** uporządkowane

# %%
col_map = LinearSegmentedColormap.from_list('col_map', [(0,0,0),(0.92, 0.2, 0.66)], N=2)
col_map2 = LinearSegmentedColormap.from_list('col_map', [(0.92, 0.2, 0.66),(0.92, 0.2, 0.66)], N=2)

# %%
L10_T1 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T1.npy', allow_pickle=True)
plt.imshow(L10_T1[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1[100], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T1[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T1[8000], cmap=col_map2)
plt.show()

# %% [markdown]
# **L=10, T=2.26**

# %%
L10_T2 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T2.npy', allow_pickle=True)
plt.imshow(L10_T2[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T2[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=10, T=4**

# %%
L10_T3 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T3.npy', allow_pickle=True)
plt.imshow(L10_T3[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T3[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=1** uporządkowane

# %%
L100_T1 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T1.npy', allow_pickle=True)
plt.imshow(L100_T1[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L100_T1[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1[7000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1[10000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=2.26**

# %%
L100_T2 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T2.npy', allow_pickle=True)
plt.imshow(L100_T2[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L100_T2[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2[7000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2[10000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=4**

# %%
L100_T3 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T3.npy', allow_pickle=True)
plt.imshow(L100_T3[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L100_T3[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3[7000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3[10000], cmap=col_map)
plt.show()

# %% [markdown]
# L=10, T=1.7

# %%
m10 = []
for i in range(1,10):
    m10.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m10_1.7\\m10_T1.7'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m10[:6]:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4,0,1])
plt.title('Trajektorie L=10 dla T*=1.7',fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.savefig('trajektorie_L10')

# %% [markdown]
# L=50, T=1.7

# %%
m50 = []
for i in range(1,7):
    m50.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m50_1.7\\m50_T1.7'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m50:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4,0.92,1])
plt.title('Trajektorie L=50 dla T*=1.7',fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.savefig('trajektorie_L50')

# %% [markdown]
# L=100, T=1.7

# %%
m100 = []
for i in range(1,7):
    m100.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m100_1.7\\m100_T1.7'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m100:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4,0.94,1])
plt.title('Trajektorie L=100 dla T*=1.7',fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.savefig('trajektorie_L100')

# %% [markdown]
# m(t)

# %%
t_range = np.arange(1,2,0.2)
t_range = np.append(t_range,np.arange(2,2.6,0.05))
t_range = np.append(t_range,np.arange(2.6,3.5,0.2))

# %%
m10_zakres = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m10_zakres.npy', allow_pickle=True)
m10_1=[]
for i in m10_zakres:
    m10_1.append(sum(abs(k) for k in i[10**4:])/len(i[10**4:]))

# %%
m50_zakres = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m50_zakres.npy', allow_pickle=True)
m50_1=[]
for i in m50_zakres:
    m50_1.append(sum(abs(k) for k in i[10**4:])/len(i[10**4:]))

# %%
m100_zakres = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m100_zakres.npy', allow_pickle=True)
m100_1=[]
for i in m100_zakres:
    m100_1.append(sum(abs(k) for k in i[10**4:])/len(i[10**4:]))

# %%
m10 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m10av.txt')
m50 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m50av.txt')
m100 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m100av.txt')

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range,m10, '-o', color='hotpink', label='L=10')
plt.plot(t_range,m50, '-o', color='purple', label='L=50')
plt.plot(t_range,m100, '-o', color='skyblue', label='L=100')
plt.grid()
plt.legend()
plt.title('<m>(T*)',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('<m>', fontsize=15)
plt.savefig('magnetyzacja')

# %% [markdown]
# X(t)

# %%
t_range = np.arange(1,2,0.2)
t_range = np.append(t_range,np.arange(2,2.6,0.05))
t_range = np.append(t_range,np.arange(2.6,3.5,0.2))

# %%
m10_2=[]
for i in m10_zakres:
    m10_2.append(sum(k**2 for k in i[10**4:])/len(i[10**4:]))
pod_10 = []
for i in range(len(m10_2)):
    pod_10.append((m10_2[i]-(m10_1[i])**2)*10**2/t_range[i])

# %%
m50_2=[]
for i in m50_zakres:
    m50_2.append(sum(k**2 for k in i[10**4:])/len(i[10**4:]))
pod_50 = []
for i in range(len(m50_2)):
    pod_50.append((m50_2[i]-(m50_1[i])**2)*50**2/t_range[i])

# %%
m100_2=[]
for i in m100_zakres:
    m100_2.append(sum(k**2 for k in i[10**4:])/len(i[10**4:]))
pod_100 = []
for i in range(len(m100_2)):
    pod_100.append((m100_2[i]-(m100_1[i])**2)*100**2/t_range[i])

# %%
pod10 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m10avpod.txt')
pod50 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m50avpod.txt')
pod100 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m100avpod.txt')

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range,pod10, '-o', color='hotpink', label='L=10')
plt.plot(t_range,pod50, '-o', color='purple', label='L=50')
plt.plot(t_range,pod100, '-o', color='skyblue', label='L=100')
plt.grid()
plt.legend()
plt.title('\u03C7(T*) ',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('\u03C7', fontsize=15)
plt.savefig('podatnosc_magnetyczna')

# %% [markdown]
# **L=10, T=1** nieuporządkowane

# %%
L10_T1_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T1_uno.npy', allow_pickle=True)
plt.imshow(L10_T1_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T1_uno[100], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1_uno[1000], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1_uno[4000], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1_uno[8000], cmap=col_map2)
plt.show()

# %% [markdown]
# **L=10, T=2.26** nieuporządkowane

# %%
L10_T2_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T2_uno.npy', allow_pickle=True)
plt.imshow(L10_T2_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=10, T=4** nieuporządkowane

# %%
L10_T3_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T3_uno.npy', allow_pickle=True)
plt.imshow(L10_T3_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=1** nieuporządkowane

# %%
L100_T1_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T1_uno.npy', allow_pickle=True)
plt.imshow(L100_T1_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=2.26** nieuporządkowane

# %%
L100_T2_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T2_uno.npy', allow_pickle=True)
plt.imshow(L100_T2_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=4** nieuporządkowane

# %%
L100_T3_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T3_uno.npy', allow_pickle=True)
plt.imshow(L100_T3_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# L=10, T=1.7

# %%
m10_uno = []
for i in range(10):
    m10_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m10_uno\\m10_uno'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m10_uno:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4, -1, 1])
plt.title('Trajektorie dla L=10, T*=1.7', fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.savefig('trajektorie_UNO_L10')

# %% [markdown]
# L=50, T=1.7

# %%
m50_uno = []
for i in range(10):
    m50_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m50_uno\\m50_uno'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m50_uno:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4, -1, 1])
plt.title('Trajektorie dla L=50, T*=1.7', fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.savefig('trajektorie_UNO_L50')

# %% [markdown]
# L=100, T=1.7

# %%
m100_uno = []
for i in range(10):
    m100_uno.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m100_uno\\m100_uno'+str(i)+'.txt'))

# %%
plt.figure(figsize=(15,5))
for i in m100_uno:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4, -1, 1])
plt.title('Trajektorie dla L=100, T*=1.7', fontsize=20)
plt.xlabel('t [MCS]', fontsize=15)
plt.ylabel('m', fontsize=15)
plt.savefig('trajektorie_UNO_L100')

# %% [markdown]
# Rozkład magnetyzacji, T=1.7

# %%
test = []
for i in range(101):
    test.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\test\\m100_T1.7prob'+str(i)+'.txt'))

# %%
t0 = []
t100 = []
t1000 = []
t2000 = []
t10000 = []
t100000 = []
for i in test:
    t0.append(i[0])
    t100.append(i[100])
    t1000.append(i[1000])
    t2000.append(i[2000])
    t10000.append(i[10000])
    t100000.append(i[100000])

# %%
plt.figure(figsize=(8,5))
plt.hist(t0, density=True)
plt.xlim([-1,1])
plt.title('t=0', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_17den_t0')

# %%
plt.figure(figsize=(8,5))
plt.hist(t100, bins=30, density=True)
plt.xlim([-1,1])
plt.title('t=100', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_17_dent100')

# %%
plt.figure(figsize=(8,5))
plt.hist(t1000, bins=30, density=True)
plt.title('t=1000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_17den_t1000')

# %%
plt.figure(figsize=(8,5))
plt.hist(t2000, bins=30, density=True)
plt.title('t=2000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_17den_t2000')

# %%
plt.figure(figsize=(8,5))
plt.hist(t10000, bins=30, density=True)
plt.title('t=10000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_17den_t10000')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(t100000, bins=30, density=True)
plt.title('t=100000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_17den_t100000')
plt.show()

# %% [markdown]
# Rozkład magnetyzacji, T=2.26

# %%
test2 = []
for i in range(101):
    test2.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\test\\m100_T2.26prob'+str(i)+'.txt'))

# %%
t01 = []
t1001 = []
t10001 = []
t20001 = []
t100001 = []
t1000001 = []
for i in test2:
    t01.append(i[0])
    t1001.append(i[100])
    t10001.append(i[1000])
    t20001.append(i[2000])
    t100001.append(i[10000])
    t1000001.append(i[100000])

# %%
plt.figure(figsize=(8,5))
plt.hist(t01, density=True)
plt.xlim([-1,1])
plt.title('t=0', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_226den_t0')

# %%
plt.figure(figsize=(8,5))
plt.hist(t1001, bins=20, density=True)
plt.xlim([-1,1])
plt.title('t=100', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_226den_t100')

# %%
plt.figure(figsize=(8,5))
plt.hist(t10001, bins=40, density=True)
plt.xlim([-1,1])
#plt.ylim([0,10])
plt.title('t=1000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_226den_t1000')

# %%
plt.figure(figsize=(8,5))
plt.hist(t20001, bins=30, density=True)
plt.xlim([-1,1])
#plt.ylim([0,20])
plt.title('t=2000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_226den_t2000')

# %%
plt.figure(figsize=(8,5))
plt.hist(t100001, bins=30, density=True)
plt.xlim([-1,1])
#plt.ylim([0,17])
plt.title('t=10000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_226den_t10000')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(t1000001, bins=30, density=True)
plt.xlim([-1,1])
#plt.ylim([0,17])
plt.title('t=100000', fontsize=20)
plt.xlabel('m', fontsize=15)
plt.ylabel('P(t)', fontsize=15)
plt.savefig('rozklad_mag_226den_t100000')
plt.show()

# %%
for i in range(10):
    p = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Pulpit\\fizyka wykresy\\pliki tekstowe\\m100_uno\\m100_uno'+str(i)+'.txt')
    np.savetxt(r'C:\\Users\\mazur\\OneDrive\\Pulpit\\fizyka wykresy\\pliki tekstowe\\m100_uno\\m100_uno'+str(i)+'.txt', p[:10**5+1])

# %% [markdown]
# Glaubera????

# %%
t_range = np.arange(1,2,0.2)
t_range = np.append(t_range,np.arange(2,2.6,0.05))
t_range = np.append(t_range,np.arange(2.6,3.5,0.2))

# %%
m10_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m10av_g_.txt')
m50_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m50av_g_.txt')
m100_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m100av_g_.txt')

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range,m10_g, '-o', color='hotpink', label='G, L=10')
plt.plot(t_range,m50_g, '-o', color='purple', label='G, L=50')
plt.plot(t_range,m100_g, '-o', color='skyblue', label='L=100')
plt.plot(t_range,m10, '-<', color='pink', label='M, L=10')
plt.plot(t_range,m50, '-<', color='violet', label='M, L=50')
plt.plot(t_range,m100, '-<', color='skyblue', label='M, L=100')
plt.grid()
plt.legend()
plt.title('<m>(T*)',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('<m>', fontsize=15)
plt.savefig('magnetyzacja')

# %%
pod10_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m10av_g_pod.txt')
pod50_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m50av_g_pod.txt')
pod100_g = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m100av_g_pod.txt')

# %%
plt.figure(figsize=(8,5))
plt.plot(t_range,pod10_g, '-o', color='hotpink', label='G, L=10')
plt.plot(t_range,pod50_g, '-o', color='purple', label='G, L=50')
plt.plot(t_range,pod100_g, '-o', color='skyblue', label='G, L=100')
plt.plot(t_range,pod10, '-<', color='pink', label='M, L=10')
plt.plot(t_range,pod50, '-<', color='violet', label='M, L=50')
plt.plot(t_range,pod100, '-<', color='skyblue', label='M, L=100')
plt.grid()
plt.legend()
plt.title('\u03C7(T*) ',fontsize=15)
plt.xlabel('T*', fontsize=15)
plt.ylabel('\u03C7', fontsize=15)
plt.savefig('podatnosc_magnetyczna_g')

# %% [markdown]
# Glaubera????

# %%
"\u0105"
# Out:
# 'ą'

# %%
convert('U+0105')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d58e5a77c3e5> in <module>
# ----> 1 strcpy('U+0105')
#
# NameError: name 'strcpy' is not defined

# %%
"\N{GREEK CAPITAL LETTER DELTA}"
# Out:
# 'Δ'
