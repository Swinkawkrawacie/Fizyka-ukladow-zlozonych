# %%
import numpy as np
import math
import random
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %% [markdown]
# Algorytm Metropolisa

# %% [markdown]
# **L=10, T=1** uporządkowane

# %%
col_map = LinearSegmentedColormap.from_list('col_map', [(0,0,0),(0.92, 0.2, 0.66)], N=2)
col_map2 = LinearSegmentedColormap.from_list('col_map', [(0.92, 0.2, 0.66),(0.92, 0.2, 0.66)], N=2)

# %%
L10_T1 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T1.npy', allow_pickle=True)
plt.imshow(L10_T1[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1[100], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T1[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T1[8000], cmap=col_map2)
plt.show()

# %% [markdown]
# **L=10, T=2.26**

# %%
L10_T2 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T2.npy', allow_pickle=True)
plt.imshow(L10_T2[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T2[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=10, T=4**

# %%
L10_T3 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T3.npy', allow_pickle=True)
plt.imshow(L10_T3[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T3[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=1** uporządkowane

# %%
L100_T1 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T1.npy', allow_pickle=True)
plt.imshow(L100_T1[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L100_T1[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1[7000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1[10000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=2.26**

# %%
L100_T2 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T2.npy', allow_pickle=True)
plt.imshow(L100_T2[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L100_T2[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2[7000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2[10000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=4**

# %%
L100_T3 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T3.npy', allow_pickle=True)
plt.imshow(L100_T3[0], cmap=col_map2)
plt.show()

# %%
plt.imshow(L100_T3[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3[7000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3[10000], cmap=col_map)
plt.show()

# %% [markdown]
# L=10, T=1.7

# %%
m10 = []
for i in range(1,10):
    m10.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m10_1.7\\m10_T1.7'+str(i)+'.txt'))

# %%
plt.figure(figsize=(20,5))
for i in m10[:5]:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4,-1,1])
plt.show()

# %% [markdown]
# L=50, T=1.7

# %%
m50 = []
for i in range(1,10):
    m50.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m50_1.7\\m50_T1.7'+str(i)+'.txt'))

# %%
plt.figure(figsize=(20,5))
for i in m50[:5]:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4,0.9,1])
plt.show()

# %% [markdown]
# L=100, T=1.7

# %%
m100 = []
for i in range(1,4):
    m100.append(np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\m100_1.7\\m100_T1.7'+str(i)+'.txt'))

# %%
plt.figure(figsize=(20,5))
for i in m100:
    plt.plot(range(len(i)), i)
plt.axis([0, 10**4,0.94,1])
plt.show()

# %% [markdown]
# m(t)

# %%
t_range = np.arange(1,2,0.2)
t_range = np.append(t_range,np.arange(2,2.6,0.1))
t_range = np.append(t_range,np.arange(2.6,3.5,0.2))

# %%
m10_zakres = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m10_zakres.npy', allow_pickle=True)
m10=[]
for i in m10_zakres:
    m10.append(sum(abs(k) for k in i[10**3:10**4])/len(i[10**3:10**4]))

# %%
m50_zakres = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m50_zakres.npy', allow_pickle=True)
m50=[]
for i in m50_zakres:
    m50.append(sum(abs(k) for k in i[10**3:10**4])/len(i[10**3:10**4]))

# %%
m100_zakres = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m100_zakres.npy', allow_pickle=True)
m100=[]
for i in m100_zakres:
    m100.append(sum(abs(k) for k in i[10**3:10**4])/len(i[10**3:10**4]))

# %%
plt.plot(t_range,m10, '-o', color='hotpink', label='L=10')
plt.plot(t_range,m50, '-o', color='purple', label='L=50')
plt.plot(t_range,m100, '-o', color='skyblue', label='L=100')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# X(t)

# %%
m10_2=[]
for i in m10_zakres:
    m10_2.append(sum(k**2 for k in i[10**3:10**4])/len(i[10**3:10**4]))
pod_10 = []
for i in range(len(m10_2)):
    pod_10.append((m10_2[i]-(m10[i])**2)*10**2/t_range[i])

# %%
m50_2=[]
for i in m50_zakres:
    m50_2.append(sum(k**2 for k in i[10**3:10**4])/len(i[10**3:10**4]))
pod_50 = []
for i in range(len(m50_2)):
    pod_50.append((m50_2[i]-(m50[i])**2)*50**2/t_range[i])

# %%
m100_2=[]
for i in m100_zakres:
    m100_2.append(sum(k**2 for k in i[10**3:10**4])/len(i[10**3:10**4]))
pod_100 = []
for i in range(len(m100_2)):
    pod_100.append((m100_2[i]-(m100[i])**2)*100**2/t_range[i])

# %%
plt.plot(t_range,pod_10, '-o', color='hotpink', label='L=10')
plt.plot(t_range,pod_50, '-o', color='purple', label='L=50')
plt.plot(t_range,pod_100, '-o', color='skyblue', label='L=100')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# **L=10, T=1** nieuporządkowane

# %%
L10_T1_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T1_uno.npy', allow_pickle=True)
plt.imshow(L10_T1_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T1_uno[100], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1_uno[1000], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1_uno[4000], cmap=col_map2)
plt.show()

# %%
plt.imshow(L10_T1_uno[8000], cmap=col_map2)
plt.show()

# %% [markdown]
# **L=10, T=2.26** nieuporządkowane

# %%
L10_T2_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T2_uno.npy', allow_pickle=True)
plt.imshow(L10_T2_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T2_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=10, T=4** nieuporządkowane

# %%
L10_T3_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L10_T3_uno.npy', allow_pickle=True)
plt.imshow(L10_T3_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L10_T3_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=1** nieuporządkowane

# %%
L100_T1_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T1_uno.npy', allow_pickle=True)
plt.imshow(L100_T1_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T1_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=2.26** nieuporządkowane

# %%
L100_T2_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T2_uno.npy', allow_pickle=True)
plt.imshow(L100_T2_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T2_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=4** nieuporządkowane

# %%
L100_T3_uno = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane\\L100_T3_uno.npy', allow_pickle=True)
plt.imshow(L100_T3_uno[0], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[100], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[4000], cmap=col_map)
plt.show()

# %%
plt.imshow(L100_T3_uno[8000], cmap=col_map)
plt.show()

# %% [markdown]
# L=10, T=1.7

# %%
m10_uno = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m10_uno.txt')
plt.figure(figsize=(20,5))
plt.plot(range(len(m10_uno)), m10_uno, 'g')
plt.axis([0, 10**4, -1, 1])
plt.show()

# %%
m10_uno_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m10_uno1.txt')
m10_uno_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m10_uno2.txt')
m10_uno_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m10_uno3.txt')
m10_uno_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m10_uno4.txt')

# %%
plt.figure(figsize=(20,5))
plt.plot(range(len(m10_uno)), m10_uno)
plt.plot(range(len(m10_uno_1)), m10_uno_1)
plt.plot(range(len(m10_uno_2)), m10_uno_2)
plt.plot(range(len(m10_uno_3)), m10_uno_3)
plt.plot(range(len(m10_uno_4)), m10_uno_4)
plt.axis([0, 10**4, -1, 1])
plt.show()

# %% [markdown]
# L=50, T=1.7

# %%
m50_uno = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m50_uno.txt')
plt.figure(figsize=(20,5))
plt.plot(range(len(m50_uno)), m50_uno, 'g')
plt.axis([0, 10**4, -1, 1])
plt.show()

# %%
m50_uno_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m50_uno1.txt')
m50_uno_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m50_uno2.txt')
m50_uno_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m50_uno3.txt')
m50_uno_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m50_uno4.txt')

# %%
plt.figure(figsize=(20,5))
plt.plot(range(len(m50_uno)), m50_uno)
plt.plot(range(len(m50_uno_1)), m50_uno_1)
plt.plot(range(len(m50_uno_2)), m50_uno_2)
plt.plot(range(len(m50_uno_3)), m50_uno_3)
plt.plot(range(len(m50_uno_4)), m50_uno_4)
plt.axis([0, 10**4, -1, 1])
plt.show()

# %% [markdown]
# L=100, T=1.7

# %%
m100_uno = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m100_uno.txt')
plt.figure(figsize=(20,5))
plt.plot(range(len(m100_uno)), m100_uno, 'g')
plt.axis([0, 10**4, 0, 1])
plt.show()

# %%
m100_uno_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m100_uno1.txt')
m100_uno_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m100_uno2.txt')
m100_uno_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m100_uno3.txt')
m100_uno_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\m100_uno4.txt')

# %%
plt.figure(figsize=(20,5))
plt.plot(range(len(m100_uno)), m100_uno)
plt.plot(range(len(m100_uno_1)), m100_uno_1)
plt.plot(range(len(m100_uno_2)), m100_uno_2)
plt.plot(range(len(m100_uno_3)), m100_uno_3)
plt.plot(range(len(m100_uno_4)), m100_uno_4)
plt.axis([0, 10**4, -1, 1])
plt.show()

# %%
test0 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T2.26_0_.txt')
test100 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T2.26_100_.txt')
test1000 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T2.26_1000_.txt')
test4000 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T2.26_4000_.txt')
test10000 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T2.26_8000_.txt')

# %%
plt.imshow(test0, cmap=col_map2)
plt.show()

# %%
plt.imshow(test100, cmap=col_map)
plt.show()

# %%
plt.imshow(test1000, cmap=col_map)
plt.show()

# %%
plt.imshow(test4000, cmap=col_map)
plt.show()

# %%
plt.imshow(test10000, cmap=col_map)
plt.show()

# %%
testm = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\m10_T2.26.txt')

# %%
plt.plot(range(len(testm)), testm)
plt.axis([0, 10**4, -1, 1])
plt.show()

# %%
test01 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T1.7_0_.txt')
test1001 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T1.7_100_.txt')
test10001 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T1.7_1000_.txt')
test40001 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T1.7_4000_.txt')
test100001 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\L10_T1.7_8000_.txt')

# %%
plt.imshow(test01, cmap=col_map2)
plt.show()

# %%
plt.imshow(test1001, cmap=col_map2)
plt.show()

# %%
plt.imshow(test10001, cmap=col_map)
plt.show()

# %%
plt.imshow(test40001, cmap=col_map2)
plt.show()

# %%
plt.imshow(test100001, cmap=col_map2)
plt.show()

# %%
testm1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\dane1\\m10_T1.7.txt')

# %%
plt.plot(range(len(testm)), testm)
plt.axis([0, 10**4, -1, 1])
plt.show()

# %%
2+2
# Out:
# 4
