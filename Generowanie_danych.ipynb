# %%
import numpy as np
import math
import random
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %% [markdown]
# Algorytm Metropolisa

# %%
def alg_met(L,T,K, file_name):
    b = [i for i in range(-1,L+1)]
    b[0] = L-1
    b[L+1] = 0
    kb = 1 #stała boltzmana
    J = 1
    N=L**2
    name_count=0
    S = np.ones((L,L))
    #S = np.random.choice([-1,1],(L,L))
    np.savetxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T2\\'+file_name+str(name_count)+'.txt',S)
    #m_data = [1/N*sum(sum(S))]
    for z in range(K):
        op_count=0
        name_count+=1
        while op_count<N:
            op_count += 1
            i = math.floor(random.random()*L)
            j = math.floor(random.random()*L)
            dE=2*J*S[i][j]*(S[b[i]][j] + S[b[i+2]][j] + S[i][b[j]] + S[i][b[j+2]])
            if dE<=0:
                S[i][j] *= -1
            else:
                x = random.random()
                if x<math.exp(-dE/(kb*T)):
                    S[i][j] *= -1
        #m_data.append(1/N*sum(sum(S)))
        if name_count%100==0:
            np.savetxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T2\\'+file_name+str(name_count)+'.txt',S)
    #np.savetxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\'+file_name+'m.txt',m_data)

# %% [markdown]
# **L=10, T=1** uporządkowane

# %%
col_map = LinearSegmentedColormap.from_list('col_map', [(0,0,0),(0.92, 0.2, 0.66)], N=2)
col_map2 = LinearSegmentedColormap.from_list('col_map', [(0.92, 0.2, 0.66),(0.92, 0.2, 0.66)], N=2)
L10_T1_0 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1\\L10_T1_0.txt')
plt.imshow(L10_T1_0, cmap=col_map2)
plt.show()

# %%
L10_T1_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1\\L10_T1_100.txt')
plt.imshow(L10_T1_1, cmap=col_map2)
plt.show()

# %%
L10_T1_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1\\L10_T1_1000.txt')
plt.imshow(L10_T1_2, cmap=col_map2)
plt.show()

# %%
L10_T1_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1\\L10_T1_10000.txt')
plt.imshow(L10_T1_3, cmap=col_map2)
plt.show()

# %%
L10_T1_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1\\L10_T1_100000.txt')
plt.imshow(L10_T1_4, cmap=col_map2)
plt.show()

# %% [markdown]
# **L=10, T=1** nieuporządkowane

# %%
L10_T1_uno_0 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1_uno\\L10_T1_uno_0.txt')
plt.imshow(L10_T1_uno_0, cmap=col_map)
plt.show()

# %%
L10_T1_uno_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1_uno\\L10_T1_uno_100.txt')
plt.imshow(L10_T1_uno_1, cmap=col_map)
plt.show()

# %%
L10_T1_uno_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1_uno\\L10_T1_uno_1000.txt')
plt.imshow(L10_T1_uno_2, cmap=col_map2)
plt.show()

# %%
L10_T1_uno_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1_uno\\L10_T1_uno_10000.txt')
plt.imshow(L10_T1_uno_3, cmap=col_map2)
plt.show()

# %%
L10_T1_uno_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T1_uno\\L10_T1_uno_100000.txt')
plt.imshow(L10_T1_uno_4, cmap=col_map2)
plt.show()

# %% [markdown]
# **L=10, T=2.26**

# %%
L10_T2_0 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T2\\L10_T2_0.txt')
plt.imshow(L10_T2_0, cmap=col_map2)
plt.show()

# %%
L10_T2_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T2\\L10_T2_100.txt')
plt.imshow(L10_T2_1, cmap=col_map)
plt.show()

# %%
L10_T2_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T2\\L10_T2_1000.txt')
plt.imshow(L10_T2_2, cmap=col_map)
plt.show()

# %%
L10_T2_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T2\\L10_T2_10000.txt')
plt.imshow(L10_T2_3, cmap=col_map)
plt.show()

# %%
L10_T2_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T2\\L10_T2_100000.txt')
plt.imshow(L10_T2_4, cmap=col_map)
plt.show()

# %% [markdown]
# **L=10, T=4**

# %%
L10_T3_0 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T3\\L10_T3_0.txt')
plt.imshow(L10_T3_0, cmap=col_map2)
plt.show()

# %%
L10_T3_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T3\\L10_T3_100.txt')
plt.imshow(L10_T3_1, cmap=col_map)
plt.show()

# %%
L10_T3_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T3\\L10_T3_1000.txt')
plt.imshow(L10_T3_2, cmap=col_map)
plt.show()

# %%
L10_T3_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T3\\L10_T3_10000.txt')
plt.imshow(L10_T3_3, cmap=col_map)
plt.show()

# %%
L10_T3_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L10_T3\\L10_T3_100000.txt')
plt.imshow(L10_T3_4, cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=1** uporządkowane

# %%
L100_T1_0 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1\\L100_T1_0.txt')
plt.imshow(L100_T1_0, cmap=col_map2)
plt.show()

# %%
L100_T1_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1\\L100_T1_100.txt')
plt.imshow(L100_T1_1, cmap=col_map2)
plt.show()

# %%
L100_T1_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1\\L100_T1_1000.txt')
plt.imshow(L100_T1_2, cmap=col_map2)
plt.show()

# %%
L100_T1_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1\\L100_T1_10000.txt')
plt.imshow(L100_T1_3, cmap=col_map2)
plt.show()

# %%
L100_T1_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1\\L100_T1_100000.txt')
plt.imshow(L100_T1_4, cmap=col_map2)
plt.show()

# %% [markdown]
# **L=100, T=1** nieuporządkowane

# %%
L100_T1_uno_0 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1_uno\\L100_T1_uno_0.txt')
plt.imshow(L100_T1_uno_0, cmap=col_map)
plt.show()

# %%
L100_T1_uno_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1_uno\\L100_T1_uno_100.txt')
plt.imshow(L100_T1_uno_1, cmap=col_map)
plt.show()

# %%
L100_T1_uno_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1_uno\\L100_T1_uno_1000.txt')
plt.imshow(L100_T1_uno_2, cmap=col_map2)
plt.show()

# %%
L100_T1_uno_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1_uno\\L100_T1_uno_10000.txt')
plt.imshow(L100_T1_uno_3, cmap=col_map2)
plt.show()

# %%
L100_T1_uno_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T1_uno\\L100_T1_uno_100000.txt')
plt.imshow(L100_T1_uno_4, cmap=col_map2)
plt.show()

# %% [markdown]
# **L=100, T=2.26**

# %%
L100_T2_0 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T2\\L100_T20.txt')
plt.imshow(L100_T2_0, cmap=col_map2)
plt.show()

# %%
L100_T2_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T2\\L100_T21000.txt')
plt.imshow(L100_T2_1, cmap=col_map)
plt.show()

# %%
L100_T2_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T2\\L100_T210000.txt')
plt.imshow(L100_T2_2, cmap=col_map)
plt.show()

# %%
L100_T2_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T2\\L100_T250000.txt')
plt.imshow(L100_T2_3, cmap=col_map)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-341-1639dbc3c426> in <module>
# ----> 1 L100_T2_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T2\\L100_T250000.txt')
#       2 plt.imshow(L100_T2_3, cmap=col_map)
#       3 plt.show()
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ...

# %%
L100_T2_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T2\\L100_T2100000.txt')
plt.imshow(L100_T2_4, cmap=col_map)
plt.show()

# %% [markdown]
# **L=100, T=4**

# %%
L100_T3_0 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T3\\L100_T3_0.txt')
plt.imshow(L100_T3_0, cmap=col_map2)
plt.show()

# %%
L100_T3_1 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T3\\L100_T3_100.txt')
plt.imshow(L100_T3_1, cmap=col_map)
plt.show()

# %%
L100_T3_2 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T3\\L100_T3_1000.txt')
plt.imshow(L100_T3_2, cmap=col_map)
plt.show()

# %%
L100_T3_3 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T3\\L100_T3_10000.txt')
plt.imshow(L100_T3_3, cmap=col_map)
plt.show()

# %%
L100_T3_4 = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L100_T3\\L100_T3_100000.txt')
plt.imshow(L100_T3_4, cmap=col_map)
plt.show()

# %% [markdown]
# Nieuporządkowany układ, T=1.7, L=10

# %%
uno_1_7_10_m = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\uno_1_7_10m.txt')
plt.figure(figsize=(20,5))
plt.plot(range(len(uno_1_7_10_m)), uno_1_7_10_m)
plt.axis([0, 10**4, 0, 1])
plt.show()

# %% [markdown]
# Uporządkowany L=10, T=1.7

# %%
o_1_7_10_m = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\1_7_10m.txt')
plt.figure(figsize=(20,7))
plt.plot(range(len(o_1_7_10_m)), o_1_7_10_m)
plt.axis([0, 10**4, 0, 1])
plt.show()

# %% [markdown]
# Uporządkowany L=50, T=1.7

# %%
o_1_7_10_m = np.loadtxt(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\danem\\1_7_10m.txt')
plt.figure(figsize=(20,7))
plt.plot(range(len(o_1_7_10_m)), o_1_7_10_m)
plt.axis([0, 10**4, 0, 1])
plt.show()

# %%
L1_T2 = np.load(r'C:\\Users\\mazur\\OneDrive\\Dokumenty\\GitHub\\Fizyka-ukladow-zlozonych\\L1_T2\\L1_T2.txt.npy', allow_pickle=True)
plt.imshow(L1_T2[1000], cmap=col_map)
plt.show()

# %%
plt.imshow(L1_T2[1000], cmap=col_map)
plt.show()
