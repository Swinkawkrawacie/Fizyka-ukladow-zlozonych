# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
with open('data_voter\\N100dx0.02L1000.txt') as f:
    N100_data = f.readlines()
with open('data_voter\\N200dx0.02L1000.txt') as f:
    N200_data = f.readlines()
with open('data_voter\\N300dx0.02L1000.txt') as f:
    N300_data = f.readlines()
with open('data_voter\\N1000dx0.02L1000.txt') as f:
    N1000_data = f.readlines()

# %%
x = []
time_100 = []
prob_100 = []
for i in N100_data:
    new = i[:-1].split('  ')
    x.append(float(new[0]))
    prob_100.append(float(new[1]))
    time_100.append(float(new[2]))

# %%
time_200 = []
prob_200 = []
for i in N200_data:
    new = i[:-1].split('  ')
    prob_200.append(float(new[1]))
    time_200.append(float(new[2]))

# %%
time_300 = []
prob_300 = []
for i in N300_data:
    new = i[:-1].split('  ')
    prob_300.append(float(new[1]))
    time_300.append(float(new[2]))

# %%
time_1000 = []
prob_1000 = []
for i in N1000_data:
    new = i[:-1].split('  ')
    prob_1000.append(float(new[1]))
    time_1000.append(float(new[2]))

# %%
plt.figure(figsize=(8,5))
plt.plot(x, prob_100, 'o', color='hotpink', label=r'N=${10}^2$')
plt.plot(x, prob_200, 'o', color='purple', label=r'N=$2\cdot{10}^2$')
plt.plot(x, prob_300, 'o', color='skyblue', label=r'N=$3\cdot{10}^2$')
plt.plot(x, prob_1000, 'o', color='lime', label=r'N=${10}^3$')
plt.grid()
plt.legend()
plt.title('P(x)',fontsize=15)
plt.xlabel('x', fontsize=15)
plt.ylabel('P(x)', fontsize=15)
plt.savefig("prawdopodobienstwo.jpg")

# %%
plt.figure(figsize=(8,5))
plt.plot(x, time_100, 'o', color='hotpink', label=r'N=${10}^2$')
plt.plot(x, time_200, 'o', color='purple', label=r'N=$2\cdot{10}^2$')
plt.plot(x, time_300, 'o', color='skyblue', label=r'N=$3\cdot{10}^2$')
plt.plot(x, time_1000, 'o', color='lime', label=r'N=${10}^3$')
plt.grid()
plt.legend()
plt.title('\u03c4(x)',fontsize=15)
plt.xlabel('x', fontsize=15)
plt.ylabel('\u03c4(x)', fontsize=15)
plt.savefig("czas.jpg")

# %%
plt.figure(figsize=(8,5))
plt.plot(x, time_100, 'o', color='hotpink', label=r'N=${10}^2$')
plt.plot(x, time_200, 'o', color='purple', label=r'N=$2\cdot{10}^2$')
plt.plot(x, time_300, 'o', color='skyblue', label=r'N=$3\cdot{10}^2$')
plt.grid()
plt.legend()
plt.title('\u03c4(x)',fontsize=15)
plt.xlabel('x', fontsize=15)
plt.ylabel('\u03c4(x)', fontsize=15)
plt.savefig("czas_mniej.jpg")

# %%
with open('N100dx0.02L1000k.txt') as f:
    k = f.readlines()

# %%
k.sort(key=lambda y: y[0])

# %%
x = []
time_k = []
prob_k = []
for i in k:
    new = i[:-1].split('  ')
    x.append(float(new[0]))
    prob_k.append(float(new[1]))
    time_k.append(float(new[2]))

# %%
plt.figure(figsize=(8,5))
plt.plot(x, prob_k, 'o', color='hotpink', label=r'N=${10}^2$')
plt.grid()
plt.legend()
plt.title('P(x)',fontsize=15)
plt.xlabel('x', fontsize=15)
plt.ylabel('P(x)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(x, time_k, 'o', color='hotpink', label=r'N=${10}^2$')
plt.grid()
plt.legend()
plt.title('\u03c4(x)',fontsize=15)
plt.xlabel('x', fontsize=15)
plt.ylabel('\u03c4(x)', fontsize=15)
plt.show()

# %%
with open('data_voter_easier\\N100dx0.05L100.txt') as f:
    N_100_data = f.readlines()
with open('data_voter_easier\\N200dx0.05L100.txt') as f:
    N_200_data = f.readlines()
with open('data_voter_easier\\N500dx0.05L100.txt') as f:
    N_500_data = f.readlines()

# %%
x = []
time100 = []
prob100 = []
for i in N_100_data:
    new = i[:-1].split('  ')
    x.append(float(new[0]))
    prob100.append(float(new[1]))
    time100.append(float(new[2]))
time200 = []
prob200 = []
for i in N_200_data:
    new = i[:-1].split('  ')
    prob200.append(float(new[1]))
    time200.append(float(new[2]))
time500 = []
prob500 = []
for i in N_500_data:
    new = i[:-1].split('  ')
    prob500.append(float(new[1]))
    time500.append(float(new[2]))

# %%
plt.figure(figsize=(8,5))
plt.plot(x, prob100, 'o', color='hotpink', label=r'N=${10}^2$')
plt.plot(x, prob200, 'o', color='purple', label=r'N=$2\cdot{10}^2$')
plt.plot(x, prob500, 'o', color='skyblue', label=r'N=$5\cdot{10}^2$')
plt.grid()
plt.legend()
plt.title('P(x)',fontsize=15)
plt.xlabel('x', fontsize=15)
plt.ylabel('P(x)', fontsize=15)
plt.savefig("prawdopodobienstwo_easier.jpg")

# %%
plt.figure(figsize=(8,5))
plt.plot(x, time100, 'o', color='hotpink', label=r'N=${10}^2$')
plt.plot(x, time200, 'o', color='purple', label=r'N=$2\cdot{10}^2$')
plt.plot(x, time500, 'o', color='skyblue', label=r'N=$5\cdot{10}^2$')
plt.grid()
plt.legend()
plt.title('\u03c4(x)',fontsize=15)
plt.xlabel('x', fontsize=15)
plt.ylabel('\u03c4(x)', fontsize=15)
plt.savefig("czas_easier.jpg")
